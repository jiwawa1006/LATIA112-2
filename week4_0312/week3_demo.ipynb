# %% [markdown]
# from google colab import files #匯入套件
#
# import pandas as pd
#
# upload = files.upload() #開啟上傳介面並載入
#
# data = pd.read_csv("剛剛上傳的檔案名稱")

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)

import os
os.chdir("/content/gdrive/My Drive/112_2_LATIA/week3_030524/") # 切換目錄
#!ls -l "/content/gdrive/My Drive/112_2_LATIA/week3_030524/" # 列出目錄下的檔案
# !ls -l "112_student.csv"
# Out:
# Mounted at /content/gdrive/
# -rw------- 1 root root 92484 Mar  5 06:42 112_student.csv

# %%
import pandas as pd

#csv_file = './112_student.csv'
csv_file ="112_student.csv"

#columns = [
#    "學年度","學校代碼","學校名稱","日間∕進修別","等級別","總計","男生計",
#    "女生計","一年級男","一年級女","二年級男","二年級女","三年級男","三年級女",
#    "四年級男","四年級女","五年級男","五年級女","六年級男","六年級女",
#    "七年級男","七年級女","延修生男","延修生女","縣市名稱","體系別"
#]
df = pd.read_csv(csv_file) # 讀取csv檔案
print(df.head())

#查看資料欄位資訊
print(df.info())

#查看資料的統計學資訊描述
#print(df.describe(include='all'))
# Out:
#    學年度  學校代碼    學校名稱 日間∕進修別   等級別    總計   男生計   女生計  一年級男  一年級女  ...  五年級男  \
# 0  112     1  國立政治大學    D 日  D 博士   921   517   404    86    69  ...    63
# 1  112     1  國立政治大學    D 日  M 碩士  4231  1835  2396   598   809  ...     2
# 2  112     1  國立政治大學    N 職  M 碩士  1903   938   965   262   304  ...    77
# 3  112     1  國立政治大學    D 日  B 學士  9763  3928  5835   906  1349  ...     0
# 4  112     2  國立清華大學    D 日  D 博士  1636  1131   505   206    93  ...   140
#
#    五年級女  六年級男  六年級女  七年級男  七年級女  延修生男  延修生女    縣市名稱   體系別
# 0    52    68    37    66    50     0     0  30 臺北市  1 一般
# 1     1     1     0     0     0     0     0  30 臺北市  1 一般
# 2    57     0     0     0     0     0     0  30 臺北市  1 一般
# 3     0     0     0     0     0   316   499  30 臺北市  1 一般
# 4    60   110    50   115    56     0     0  18 新竹市  1 一般
#
# [5 rows x 26 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 764 entries, 0 to 763
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   學年度     764 non-null    int64
#  1   學校代碼    764 non-null    int64
#  2   學校名稱    764 non-null    object
#  3   日間∕進修別  764 non-null    object
#  4   等級別     764 non-null    object
#  5   總計      764 non-null    int64
#  6   男生計     764 non-null    int64
#  7   女生計     764 non-null    int64
#  8   一年級男    764 non-null    int64
#  9   一年級女    764 non-null    int64
#  10  二年級男    764 non-null    int64
#  11  二年級女    764 non-null    int64
#  12  三年級男    764 non-null    int64
#  13  三年級女    764 non-null    int64
#  14  四年級男    764 non-null    int64
#  15  四年級女    764 non-null    int64
#  16  五年級男    764 non-null    int64
#  17  五年級女    764 non-null    int64
#  18  六年級男    764 non-null    int64
#  19  六年級女    764 non-null    int64
#  20  七年級男    764 non-null    int64
#  21  七年級女    764 non-null    int64
#  22  延修生男    764 non-null    int64
#  23  延修生女    764 non-null    int64
#  24  縣市名稱    764 non-null    object
#  25  體系別     764 non-null    object
# dtypes: int64(21), object(5)
# memory usage: 155.3+ KB
# None

# %% [markdown]
# # 1.哪間大專院校有最多的學士生
#
# step1: 取出想要查看的欄位，並印出此資料集共有多少筆紀錄 (len)
#
# step2: 篩選等級別為"B 學士"的DataFrame，並印出有招生學士學制的學校數量
#
# step3: 依據"總計"從大到小排序並印出結果 (sort_values, by, ascending)

# %%
# 請在"填空"處，輸入所需要的指令或參數

df1 = df[['學校名稱', '等級別', '總計']] # 取出想要觀看的欄位
print("本資料集共有", len(df1), "筆紀錄")

df1_1 = df1[df1['等級別'] == 'B 學士']
print("有招生學士學制的學校數量為", len(df1_1), "\n")
df1_1_sorted = df1_1.sort_values(by=['總計'], ascending=False)
print("112學年度在籍的學士生最多人數之學校為", df1_1_sorted.head(1)['學校名稱'].values)
# Out:
# 本資料集共有 764 筆紀錄
# 有招生學士學制的學校數量為 97
#
# 112學年度在籍的學士生最多人數之學校為 ['淡江大學']

# %% [markdown]
# # 2. 國立？所；私立？所
#
# step1: 建立空字串 (lsit=[])
#
# step2: 建立for迴圈，配合if else條件，取出國立與私立
#
# step3: 新增「公私立」column在DataFrame中 (df['公私立'])
#
# step4: 篩選掉重複的學校代碼資料 (drop_duplicates)
#
# step5: 計算公立與私立學校的筆數，並印出結果 (value_counts)

# %%
type_list = [] # 建立空字串

for i in df['學校名稱']:
    if ('國立' in i) or ('市立' in i):
        type_list.append('公立')
    else:
        type_list.append('私立')

df['公私立'] = type_list # 將 Dataframe 新增「公私立」column

df2 = df.drop_duplicates(subset=['學校代碼'])
count = df2['公私立'].value_counts()
print(count)

# # print(df2)
print(f"本資料集共收集了 {len(df2)} 所學校，其中公立：{count[0]} 所；私立：{count[1]} 所。")
# Out:
# 私立    98
# 公立    47
# Name: 公私立, dtype: int64
# 本資料集共收集了 145 所學校，其中公立：98 所；私立：47 所。

# %% [markdown]
# # 3. 各等級別學制共有？所
#
# step1: 篩選掉重複的學校名稱與等級別 (drop_duplicates, subset)
#
# step2: 計算出等級別的筆數 (value_counts)
#
# step3: 建立等級別的字串，並找出其類別 (unique)
#
# step4: 使用for迴圈，依序列出所有等級別學制的學校數量 (count)

# %%
df3 = df.drop_duplicates(subset=['學校名稱', '等級別'])
count = df3['等級別'].value_counts()
degree_list = list(df['等級別'].unique())

print(count)
# print(degree_list)

print(f"本資料集總共收集了 {len(set(df2['學校代碼']))} 所學校，各等級學制當中：")
for degree in degree_list:
    print(f"一共有{count[degree]} 所學校， 有招收 {degree}。")
# Out:
# M 碩士     130
# D 博士      84
# C 二技      71
# B 學士      67
# B 四技      66
# 5 五專      46
# 2 二專      46
# 5 七年       2
# X 4+X      1
# C 二年制      1
# Name: 等級別, dtype: int64
# 本資料集總共收集了 145 所學校，各等級學制當中：
# 一共有84 所學校， 有招收 D 博士。
# 一共有130 所學校， 有招收 M 碩士。
# 一共有67 所學校， 有招收 B 學士。
# 一共有1 所學校， 有招收 X 4+X。
# 一共有71 所學校， 有招收 C 二技。
# 一共有66 所學校， 有招收 B 四技。
# 一共有46 所學校， 有招收 5 五專。
# 一共有2 所學校， 有招收 5 七年。
# 一共有46 所學校， 有招收 2 二專。
# 一共有1 所學校， 有招收 C 二年制。

# %% [markdown]
# # 題目一 : 總共有幾間學校?

# %%
df01 = df.drop_duplicates(subset=['學校名稱'])
print(f"共有 {len(df01)} 所學校")
# Out:
# 共有 145 所學校

# %% [markdown]
# #題目二 : 各縣市分別有幾所學校？

# %%
df02 = df.drop_duplicates(subset=['學校名稱'])
count = df02['縣市名稱'].value_counts()
city_list = list(df['縣市名稱'].unique())

for city in city_list:
  print(f"{city[-3:]} 有 {count[city]} 所學校")
# Out:
# 臺北市 有 24 所學校
# 新竹市 有 5 所學校
# 臺南市 有 4 所學校
# 臺中市 有 11 所學校
# 桃園市 有 12 所學校
# 高雄市 有 8 所學校
# 基隆市 有 3 所學校
# 嘉義縣 有 4 所學校
# 彰化縣 有 4 所學校
# 新北市 有 20 所學校
# 嘉義市 有 2 所學校
# 花蓮縣 有 4 所學校
# 南投縣 有 2 所學校
# 雲林縣 有 3 所學校
# 屏東縣 有 5 所學校
# 臺東縣 有 2 所學校
# 宜蘭縣 有 3 所學校
# 苗栗縣 有 3 所學校
# 臺南市 有 9 所學校
# 澎湖縣 有 1 所學校
# 臺中市 有 6 所學校
# 金門縣 有 1 所學校
# 高雄市 有 7 所學校
# 新竹縣 有 2 所學校

# %% [markdown]
# # 題目三 : 所有學校各年級的學生分佈？

# %%
df03 = df.drop_duplicates(subset=['學校名稱'])

# %% [markdown]
# # 4. 各縣市分別有？所，位於新北市的大專院校總共有幾所

# %%
df4 = df.drop_duplicates(subset=['學校名稱'])
count = df4['縣市名稱'].value_counts()
city_list = list(df['縣市名稱'].unique())

for city in city_list:
  print(f"{city[-3:]} 有 {count[city]} 所學校")

df4_1 = df4[df4['縣市名'] == '新北市']
df4_2 = df4_1[df4_1['公私立'] == '私立']

# print(df4_2)
print(f"\n新北市的大專院校共 {len(df4_2['學校名稱'])} 所學校")
# Out:
# 臺北市 有 24 所學校
# 新竹市 有 5 所學校
# 臺南市 有 4 所學校
# 臺中市 有 11 所學校
# 桃園市 有 12 所學校
# 高雄市 有 8 所學校
# 基隆市 有 3 所學校
# 嘉義縣 有 4 所學校
# 彰化縣 有 4 所學校
# 新北市 有 20 所學校
# 嘉義市 有 2 所學校
# 花蓮縣 有 4 所學校
# 南投縣 有 2 所學校
# 雲林縣 有 3 所學校
# 屏東縣 有 5 所學校
# 臺東縣 有 2 所學校
# 宜蘭縣 有 3 所學校
# 苗栗縣 有 3 所學校
# 臺南市 有 9 所學校
# 澎湖縣 有 1 所學校
# 臺中市 有 6 所學校
# 金門縣 有 1 所學校
# 高雄市 有 7 所學校
# 新竹縣 有 2 所學校
#      學年度  學校代碼        學校名稱 日間∕進修別   等級別   總計  男生計  女生計  一年級男  一年級女  ...  六年級女  \
# 240  112  1002        輔仁大學    D 日  D 博士  428  235  193    51    20  ...    20
# 255  112  1005        淡江大學    D 日  D 博士  351  229  122    48    23  ...    15
# 295  112  1013        華梵大學    D 日  D 博士   64   29   35     7     7  ...     3
# 335  112  1021        真理大學    D 日  M 碩士  124   65   59    21    19  ...     2
# 459  112  1041      明志科技大學    D 日  D 博士   62   45   17    18     5  ...     0
# 477  112  1044     聖約翰科技大學    D 日  M 碩士   37   29    8     0     0  ...     0
# 537  112  1054      景文科技大學    D 日  M 碩士    3    3    0     0     0  ...     0
# 552  112  1056      東南科技大學    D 日  M 碩士  137   76   61    26    30  ...     0
# 631  112  1073      醒吾科技大學    D 日  M 碩士   49   16   33     8     9  ...     0
# 645  112  1076      華夏科技大學    D 日  M 碩士   17   14    3     0     0  ...     0
# 659  112  1078      致理科技大學    D 日  M 碩士   54   15   39     8    21  ...     0
# 671  112  1080    宏國德霖科技大學    D 日  M 碩士   39   21   18    10     9  ...     0
# 688  112  1083    台北海洋科技大學    D 日  M 碩士  126   72   54    25    27  ...     0
# 696  112  1084      亞東科技大學    D 日  M 碩士   58   45   13    18     4  ...     0
# 713  112  1183      黎明技術學院    D 日  M 碩士   14    5    9     5     9  ...     0
# 730  112  1195       馬偕醫學院    D 日  D 博士   12   10    2     1     1  ...     0
# 735  112  1196      法鼓文理學院    D 日  D 博士   26   12   14     4     3  ...     1
# 749  112  1286  耕莘健康管理專科學校    N 修  2 二專  104    5   99     3    62  ...     0
#
#      七年級男  七年級女  延修生男  延修生女    縣市名稱   體系別  公私立  縣市名  區域
# 240    25    28     0     0  01 新北市  1 一般   私立  新北市  北部
# 255    22    14     0     0  01 新北市  1 一般   私立  新北市  北部
# 295     3     3     0     0  01 新北市  1 一般   私立  新北市  北部
# 335     0     0     0     0  01 新北市  1 一般   私立  新北市  北部
# 459     0     0     0     0  01 新北市  2 技職   私立  新北市  北部
# 477     0     0     0     0  01 新北市  2 技職   私立  新北市  北部
# 537     0     0     0     0  01 新北市  2 技職   私立  新北市  北部
# 552     0     0     0     0  01 新北市  2 技職   私立  新北市  北部
# 631     0     0     0     0  01 新北市  2 技職   私立  新北市  北部
# 645     0     0     0     0  01 新北市  2 技職   私立  新北市  北部
# 659     0     0     0     0  01 新北市  2 技職   私立  新北市  北部
# 671     0     0     0     0  01 新北市  2 技職   私立  新北市  北部
# 688     0     0     0     0  01 新北市  2 技職   私立  新北市  北部
# 696     0     0     0     0  01 新北市  2 技職   私立  新北市  北部
# 713     0     0     0     0  01 新北市  2 技職   私立  新北市  北部
# 730     0     0     0     0  01 新北市  1 一般   私立  新北市  北部
# 735     0     3     0     0  01 新北市  1 一般   私立  新北市  北部
# 749     0     0     0     2  01 新北市  2 技職   私立  新北市  北部
#
# [18 rows x 29 columns]
#
# 新北市的大專院校共 18 所學校

# %% [markdown]
# # 5. 北中南東區分別有？所
#
# 都市及區域發展統計彙編 - 國發會 https://www.ndc.gov.tw/nc_77_4402

# %% [markdown]
# 北部區域：包括臺北市、新北市、基隆市、新竹市、桃園市、新竹縣及宜蘭縣。
#
# 中部區域：包括臺中市、苗栗縣、彰化縣、南投縣及雲林縣。
#
# 南部區域：包括高雄市、臺南市、嘉義市、嘉義縣、屏東縣及澎湖縣。
#
# 東部區域：包括花蓮縣及臺東縣。
#
# 福建省：包括金門縣與連江縣。

# %%
city_list = []

for i in df['縣市名稱']:
    city_list.append(i[3:])

df['縣市名'] = city_list

city_to_area = {'臺北市':'北部',
         '新北市':'北部',
         '基隆市':'北部',
         '新竹市':'北部',
         '桃園市':'北部',
         '新竹縣':'北部',
         '宜蘭縣':'北部',
         '臺中市':'中部',
         '苗栗縣':'中部',
         '彰化縣':'中部',
         '南投縣':'中部',
         '雲林縣':'中部',
         '高雄市':'南部',
         '臺南市':'南部',
         '嘉義市':'南部',
         '嘉義縣':'南部',
         '屏東縣':'南部',
         '澎湖縣':'南部',
         '花蓮縣':'東部',
         '臺東縣':'東部',
         '金門縣':'福建省'}

df['區域'] = df['縣市名'].map(city_to_area)

df5 = df.drop_duplicates('學校代碼')
count = df5['區域'].value_counts()

area_list = list(df['區域'].unique())

print(f"本資料集共收集了 {len(df5)} 所學校，其中：")
for area in area_list:
  print(f"{area}區域有 {count[area]} 所學校")
# Out:
# 本資料集共收集了 145 所學校，其中：
# 北部區域有 69 所學校
# 南部區域有 40 所學校
# 中部區域有 29 所學校
# 東部區域有 6 所學校
# 福建省區域有 1 所學校

# %% [markdown]
# # 6. 各體系別分別有？所

# %%
df6 = df.drop_duplicates(subset=['學校名稱'])

# %% [markdown]
# # 7. 國立/私立與男女比
# 請問國立大學與私立大學在學男生女生比例為何? 延修生男生女生比例為何?

# %% [markdown]
# # 8. 國立大學在學生男女比

# %% [markdown]
#  # 9. 每校平均最多與最少人的體系

# %% [markdown]
# # 10. 將新增的欄位寫入並儲存成新的CSV檔案，並命名為112_students_tf.csv
#
# 新增的欄位有"公私立"，"縣市名"，"區域"

# %%
# df.head()
df.to_csv('/content/gdrive/My Drive/112_2_LATIA/week4_031224/112_students_tf.csv', encoding='utf-8', sep=',')
